# %% [markdown]
# # MRA*

# %% [markdown]
# ### base imports and tuning

# %%
import matplotlib.pyplot as plt
from scipy.ndimage.filters import uniform_filter1d

plt.rcParams['figure.figsize'] = [15, 5]
EPS = 0.000001

# %%
import sys
import os

search_tools_path = os.path.join(os.getcwd(), 'search_tools')
if search_tools_path not in sys.path:
    sys.path.append(search_tools_path)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### pipeline

# %%
from moving_ai.mai_map_reader import MaiReader, MaiMaps
from pipeline import Pipeline
from moving_ai.mai_map_visualizer import VisualizeMaiMap, VisualizeMaiMapGif

from algorithms.astar_heuristics import diagonal_dist
from algorithms.mrastar import MRAstar
from algorithms.wastar import WAstar
from algorithms.astar import Astar

# %%
def init_map_reader():
    map_reader_0 = MaiReader(MaiMaps.DEN001D)
    selected_task_callback = lambda t: t.start_c == (91, 23) and t.goal_c == (141, 25)
    selected_task = filter(selected_task_callback, map_reader_0.read_tasks()).__next__()
    return map_reader_0.with_task(selected_task)

map_reader = init_map_reader()

# %%
algorithms = [
    Astar(diagonal_dist),
    WAstar(diagonal_dist, 3),
    MRAstar(diagonal_dist, resolutions=(1, 3), w_1=3, w_2=3),
]

p = Pipeline(
    reader=map_reader,
    algorithms=algorithms,
    processor=VisualizeMaiMap()
)

# %%
p.run()

# %%
p.with_processor(VisualizeMaiMapGif()).run()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22092/1720071251.py in <module>
# ----> 1 p.with_processor(VisualizeMaiMapGif()).run()
#       2
#
# ~\PycharmProjects\HeuristicsBetterThan\search_tools\pipeline.py in run(self)
#      54         if isinstance(self.processor, AreaProcessor):
#      55             self.processor.area = m
# ---> 56         result = self.processor.process(a_results)
#      57         return result
#      58
#
# ~\PycharmProjects\HeuristicsBetterThan\search_tools\processors\processor.py in process(self, all_results)
#      53         if not all(len(ar[1]) == 1 for ar in all_results):
#      54             raise AttributeError('Only one task for visualization expected!')
# ---> 55         return self.process_with_area(self.area, all_results)
#      56
#      57     def is_area(self):
#
# ~\PycharmProjects\HeuristicsBetterThan\search_tools\moving_ai\mai_map_visualizer.py in process_with_area(self, area, all_results)
#     162                 ims_gen = make_images(area, er, zoom, self.step)
#     163
# --> 164                 with imageio.get_writer(i_path, mode='I') as fout:
#     165                     for i in ims_gen:
#     166                         fout.append_data(np.array(i))
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\core\functions.py in get_writer(uri, format, mode, **kwargs)
#     124
#     125     image_file = imopen(uri, "w" + mode, plugin=format)
# --> 126     return image_file.legacy_get_writer(**kwargs)
#     127
#     128
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\core\legacy_plugin_wrapper.py in legacy_get_writer(self, **kwargs)
#     145         # Note: this will break thread-safety
#     146         self._request._kwargs = kwargs
# --> 147         return self._format.get_writer(self._request)
#     148
#     149     def write(self, image, **kwargs) -> Optional[bytes]:
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\core\format.py in get_writer(self, request)
#     179                 f"Format {self.name} cannot write in {request.mode.image_mode} mode"
#     180             )
# --> 181         return self.Writer(self, request)
#     182
#     183     def can_read(self, request):
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\core\format.py in __init__(self, format, request)
#     215             self._request = request
#     216             # Open the reader/writer
# --> 217             self._open(**self.request.kwargs.copy())
#     218
#     219         @property
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\plugins\pillowmulti.py in _open(self, loop, duration, fps, palettesize, quantizer, subrectangles)
#      66             # The "0" (median cut) quantizer is by far the best
#      67
# ---> 68             fp = self.request.get_file()
#      69             self._writer = GifWriter(
#      70                 fp, subrectangles, loop, quantizer, int(palettesize)
#
# ~\anaconda3\envs\python38_env\lib\site-packages\imageio\core\request.py in get_file(self)
#     451         elif self._uri_type == URI_FILENAME:
#     452             if want_to_write:
# --> 453                 self._file = open(self.filename, "wb")
#     454             else:
#     455                 self._file = open(self.filename, "rb")
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\Iskander\\PycharmProjects\\HeuristicsBetterThan\\output\\walk-A*(h=diagonal).gif'
